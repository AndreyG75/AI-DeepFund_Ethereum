# %%
import pandas as pd
import requests
import time
from datetime import datetime, timezone

# %%
# Загрузим исходную таблицу
repos = pd.read_csv('https://raw.githubusercontent.com/AndreyG75/AI-DeepFund_Ethereum/refs/heads/main/Contest_2_POND/Datasets/data_contest_all_repos.csv')

# %%
# GitHub токен
GITHUB_TOKEN = "GITHUB_TOKEN"
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# %%
# Функция для извлечения основных метрик репозитория
def get_repo_metrics(repo_url):
    try:
        repo_path = "/".join(repo_url.split("/")[-2:])
        api_url = f"https://api.github.com/repos/{repo_path}"
        
        response = requests.get(api_url, headers=HEADERS)

        # Обработка ошибок
        if response.status_code == 403:
            print(f"Rate limit exceeded or forbidden access for {repo_url}. Retrying after a pause...")
            time.sleep(10)
            return {}
        elif response.status_code == 404:
            print(f"Repository {repo_url} not found.")
            return {}
        elif response.status_code != 200:
            print(f"Error fetching data for {repo_url}: {response.status_code}")
            return {}

        data = response.json()

        # Извлекаем основные метрики
        metrics = {
            "size": data.get("size", 0),
            "forks_count": data.get("forks_count", 0),
            "stars_count": data.get("stargazers_count", 0),
            "open_issues_count": data.get("open_issues_count", 0),
            "subscribers_count": data.get("subscribers_count", 0),
            "watchers_count": data.get("watchers_count", 0),
        }
        
        # Дата создания и последнего обновления
        created_at = data.get("created_at")
        updated_at = data.get("updated_at")
        if created_at:
            metrics["age_days"] = (datetime.now(timezone.utc) - datetime.strptime(created_at, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)).days
        else:
            metrics["age_days"] = None

        if updated_at:
            metrics["days_since_update"] = (datetime.now(timezone.utc) - datetime.strptime(updated_at, "%Y-%m-%dT%H:%M:%SZ").replace(tzinfo=timezone.utc)).days
        else:
            metrics["days_since_update"] = None

        return metrics

    except Exception as e:
        print(f"Exception: {e}")
        return {}

# %%
# Функция для извлечения дополнительных метрик (спонсоры, релизы и т.д.)
def get_additional_metrics(repo_url):
    try:
        repo_path = "/".join(repo_url.split("/")[-2:])
        additional_metrics = {}

        # Считаем спонсоров
        sponsors_api = f"https://api.github.com/repos/{repo_path}/sponsors"
        sponsors_response = requests.get(sponsors_api, headers=HEADERS)
        additional_metrics["sponsor_count"] = sponsors_response.json().get("sponsorships_as_maintainer", 0) if sponsors_response.status_code == 200 else 0

        # Считаем релизы
        releases_api = f"https://api.github.com/repos/{repo_path}/releases"
        releases_response = requests.get(releases_api, headers=HEADERS)
        additional_metrics["releases_count"] = len(releases_response.json()) if releases_response.status_code == 200 else 0

        # Считаем pull requests
        pulls_api = f"https://api.github.com/repos/{repo_path}/pulls?state=all"
        pulls_response = requests.get(pulls_api, headers=HEADERS)
        additional_metrics["pull_requests_count"] = len(pulls_response.json()) if pulls_response.status_code == 200 else 0

        # Считаем контрибьюторов
        contributors_api = f"https://api.github.com/repos/{repo_path}/contributors"
        contributors_response = requests.get(contributors_api, headers=HEADERS)
        additional_metrics["contributors_count"] = len(contributors_response.json()) if contributors_response.status_code == 200 else 0

        # Считаем деплои
        deployments_api = f"https://api.github.com/repos/{repo_path}/deployments"
        deployments_response = requests.get(deployments_api, headers=HEADERS)
        additional_metrics["deployments_count"] = len(deployments_response.json()) if deployments_response.status_code == 200 else 0

        # Количество используемых пакетов (если доступно через API)
        packages_api = f"https://api.github.com/repos/{repo_path}/packages"
        packages_response = requests.get(packages_api, headers=HEADERS)
        additional_metrics["num_packages_count"] = len(packages_response.json()) if packages_response.status_code == 200 else 0

        return additional_metrics

    except Exception as e:
        print(f"Exception: {e}")
        return {}

# %%
# Применение функций к каждой строке таблицы
all_repo_data = []

for _, row in repos.iterrows():
    repo_url = row['repo']
    print(f"Fetching data for {repo_url}...")

    # Получаем основные метрики
    metrics = get_repo_metrics(repo_url)

    # Получаем дополнительные метрики
    additional_metrics = get_additional_metrics(repo_url)

    # Объединяем все метрики
    combined_metrics = {**metrics, **additional_metrics, "repo_url": repo_url}
    all_repo_data.append(combined_metrics)
# Out:
# Fetching data for https://github.com/mochajs/mocha...
# Fetching data for https://github.com/chzyer/readline...
# Fetching data for https://github.com/gulpjs/gulp...
# Fetching data for https://github.com/webpack/webpack...
# Fetching data for https://github.com/redux-saga/redux-saga...
# Fetching data for https://github.com/babel/babel...
# Fetching data for https://github.com/debug-js/debug...
# Fetching data for https://github.com/vuejs/vue...
# Fetching data for https://github.com/marak/colors.js...
# Fetching data for https://github.com/reactivex/rxjs...
# Fetching data for https://github.com/webreflection/flatted...
# Fetching data for https://github.com/level/levelup...
# Fetching data for https://github.com/rollup/rollup...
# Fetching data for https://github.com/go-task/slim-sprig...
# Fetching data for https://github.com/mikemcl/bignumber.js...
# Fetching data for https://github.com/electron/electron...
# Fetching data for https://github.com/xtuc/webassemblyjs...
# Fetching data for https://github.com/gregberge/svgr...
# Fetching data for https://github.com/emotion-js/emotion...
# Fetching data for https://github.com/wooorm/markdown-table...
# Fetching data for https://github.com/sigp/lighthouse...
# Fetching data for https://github.com/ethers-io/ethers.js...
# Fetching data for https://github.com/prysmaticlabs/prysm...
# Fetching data for https://github.com/pnpm/cmd-shim...
# Fetching data for https://github.com/coinbase/coinbase-wallet-sdk...
# Fetching data for https://github.com/sindresorhus/type-fest...
# Fetching data for https://github.com/swc-project/swc...
# Fetching data for https://github.com/bradfitz/iter...
# Fetching data for https://github.com/eslint/eslint...
# Fetching data for https://github.com/walletconnect/walletconnect-monorepo...
# Fetching data for https://github.com/nomicfoundation/hardhat...
# Fetching data for https://github.com/prettier/prettier...
# Fetching data for https://github.com/qix-/color-convert...
# Fetching data for https://github.com/mafintosh/pump...
# Fetching data for https://github.com/dcodeio/long.js...
# Fetching data for https://github.com/sheetjs/js-crc32...
# Fetching data for https://github.com/zloirock/core-js...
# Fetching data for https://github.com/jedisct1/go-minisign...
# Fetching data for https://github.com/heim-rs/darwin-libproc...
# Fetching data for https://github.com/cssnano/cssnano...
# Fetching data for https://github.com/facebook/react...
# Fetching data for https://github.com/typescript-eslint/typescript-eslint...
# Fetching data for https://github.com/immerjs/immer...
# Fetching data for https://github.com/lukeed/polka...
# Fetching data for https://github.com/salesforce/tough-cookie...
# Fetching data for https://github.com/pytest-dev/pytest...
# Fetching data for https://github.com/vyperlang/vyper...
# Fetching data for https://github.com/pion/webrtc...
# Fetching data for https://github.com/ajv-validator/ajv...
# Fetching data for https://github.com/motdotla/dotenv...
# Fetching data for https://github.com/postcss/postcss...
# Fetching data for https://github.com/wighawag/hardhat-deploy...
# Fetching data for https://github.com/mozilla/source-map...
# Fetching data for https://github.com/floating-ui/floating-ui...
# Fetching data for https://github.com/browserslist/browserslist...
# Fetching data for https://github.com/consensys/teku...
# Fetching data for https://github.com/mattn/go-isatty...
# Fetching data for https://github.com/node-fetch/node-fetch...
# Fetching data for https://github.com/clap-rs/clap...
# Fetching data for https://github.com/prettier-solidity/prettier-plugin-solidity...
# Fetching data for https://github.com/yarnpkg/yarn...
# Fetching data for https://github.com/epoberezkin/fast-deep-equal...
# Fetching data for https://github.com/fb55/entities...
# Fetching data for https://github.com/ljharb/qs...
# Fetching data for https://github.com/ethereum/remix-project...
# Fetching data for https://github.com/ethereum/solidity...
# Fetching data for https://github.com/ethereum/go-ethereum...
# Fetching data for https://github.com/rich-harris/magic-string...
# Fetching data for https://github.com/axios/axios...
# Fetching data for https://github.com/webdriverio/webdriverio...
# Fetching data for https://github.com/tokio-rs/tokio...
# Fetching data for https://github.com/colorjs/color-name...
# Fetching data for https://github.com/numpy/numpy...
# Fetching data for https://github.com/vweevers/module-error...
# Fetching data for https://github.com/brooooooklyn/snappy...
# Fetching data for https://github.com/vercel/swr...
# Fetching data for https://github.com/mysticatea/abort-controller...
# Fetching data for https://github.com/import-js/eslint-plugin-import...
# Fetching data for https://github.com/getsentry/sentry-javascript...
# Fetching data for https://github.com/humanwhocodes/object-schema...
# Fetching data for https://github.com/wevm/viem...
# Fetching data for https://github.com/streetsidesoftware/cspell...
# Fetching data for https://github.com/bluealloy/revm...
# Fetching data for https://github.com/chainsafe/lodestar...
# Fetching data for https://github.com/pandas-dev/pandas...
# Fetching data for https://github.com/boa-dev/boa...
# Fetching data for https://github.com/inikulin/parse5...
# Fetching data for https://github.com/openzeppelin/openzeppelin-contracts...
# Fetching data for https://github.com/nodeca/js-yaml...
# Fetching data for https://github.com/formatjs/formatjs...
# Fetching data for https://github.com/yahoo/serialize-javascript...
# Fetching data for https://github.com/tklauser/go-sysconf...
# Fetching data for https://github.com/kaelzhang/node-ignore...
# Fetching data for https://github.com/mmcloughlin/addchain...
# Fetching data for https://github.com/google/flatbuffers...
# Fetching data for https://github.com/vitest-dev/vitest...
# Fetching data for https://github.com/crate-crypto/go-ipa...
# Fetching data for https://github.com/protofire/solhint...
# Fetching data for https://github.com/safe-global/safe-smart-account...
# Fetching data for https://github.com/supranational/blst...
# Fetching data for https://github.com/eth-infinitism/account-abstraction...
# Fetching data for https://github.com/status-im/nimbus-eth2...
# Fetching data for https://github.com/biomejs/biome...
# Fetching data for https://github.com/fastify/fastify...
# Fetching data for https://github.com/servo/rust-smallvec...
# Fetching data for https://github.com/libp2p/go-libp2p...
# Fetching data for https://github.com/paradigmxyz/reth...
# Fetching data for https://github.com/alloy-rs/core...
# Fetching data for https://github.com/web3/web3.js...
# Fetching data for https://github.com/ipfs/js-ipfs...
# Fetching data for https://github.com/ethereum/web3.py...
# Fetching data for https://github.com/erigontech/erigon...
# Fetching data for https://github.com/grandinetech/grandine...
# Fetching data for https://github.com/quic-go/quic-go...
# Fetching data for https://github.com/ethereumjs/ethereumjs-monorepo...
# Fetching data for https://github.com/alexeyraspopov/picocolors...
# Fetching data for https://github.com/ethereum/solc-js...

# %%
# Преобразуем результаты в DataFrame
result_df = pd.DataFrame(all_repo_data)

# %%
# Вывод первых строк результата для проверки
print(result_df.head())
# Out:
#     size  forks_count  stars_count  open_issues_count  subscribers_count  \
# 0  26733         3014        22698                198                397
# 1   3576          281         2109                108                 41
# 2   1118         4217        33061                 34               1025
# 3  67146         8933        64999                242               1456
# 4   9473         1967        22535                 40                249
#
#    watchers_count  age_days  days_since_update  sponsor_count  releases_count  \
# 0           22698      5084                  0              0              30
# 1            2109      3426                 15              0               6
# 2           33061      4235                  0              0              23
# 3           64999      4716                  0              0              30
# 4           22535      3356                  0              0              30
#
#    pull_requests_count  contributors_count  deployments_count  \
# 0                   30                  30                 30
# 1                   30                  30                  0
# 2                   30                  30                  0
# 3                   30                  30                  0
# 4                   30                  30                 30
#
#    num_packages_count                                  repo_url
# 0                   0          https://github.com/mochajs/mocha
# 1                   0        https://github.com/chzyer/readline
# 2                   0            https://github.com/gulpjs/gulp
# 3                   0        https://github.com/webpack/webpack
# 4                   0  https://github.com/redux-saga/redux-saga

# %%
# Сохраняем результаты в CSV файл
result_df.to_csv('deepfund_metric_git_max.csv', index=False)
